# %%
import pandas as pd 
import numpy as np

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv("Automobile_data.csv")

# Set option to display all columns
pd.set_option('display.max_columns', 27)


# Display the DataFrame to see all columns
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 200      sedan          rwd           front       109.1   188.8   68.9
# 201      sedan          rwd           front       109.1   188.8   68.8
# 202      sedan          rwd           front       109.1   188.8   68.9
# 203      sedan          rwd           front       109.1   188.8   68.9
# 204      sedan          rwd           front       109.1   188.8   68.9
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df['symboling'].value_counts()
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# normalized-losses
# ?      41
# 161    11
# 91      8
# 150     7
# 134     6
# 128     6
# 104     6
# 85      5
# 94      5
# 65      5
# 102     5
# 74      5
# 168     5
# 103     5
# 95      5
# 106     4
# 93      4
# 118     4
# 148     4
# 122     4
# 83      3
# 125     3
# 154     3
# 115     3
# 137     3
# 101     3
# 119     2
# 87      2
# 89      2
# 192     2
# 197     2
# 158     2
# 81      2
# 188     2
# 194     2
# 153     2
# 129     2
# 108     2
# 110     2
# 164     2
# 145     2
# 113     2
# 256     1
# 107     1
# 90      1
# 231     1
# 142     1
# 121     1
# 78      1
# 98      1
# 186     1
# 77      1
# Name: count, dtype: int64
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# ...

# %%
df.replace('?', np.nan, inplace=True)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df['make'] = df['make'].replace({'peugot': 'peugeot', 'alfa-romero': 'alfa-romeo'})
df
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 0            3               NaN  alfa-romeo       gas        std
# 1            3               NaN  alfa-romeo       gas        std
# 2            1               NaN  alfa-romeo       gas        std
# 3            2               164        audi       gas        std
# 4            2               164        audi       gas        std
# ..         ...               ...         ...       ...        ...
# 200         -1                95       volvo       gas        std
# 201         -1                95       volvo       gas      turbo
# 202         -1                95       volvo       gas        std
# 203         -1                95       volvo    diesel      turbo
# 204         -1                95       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df["normalized-losses"] = df["normalized-losses"].astype(float)

# %%
df["bore"] = df["bore"].astype(float)

# %%
df["stroke"] = df["stroke"].astype(float)

# %%
df["horsepower"] = df["horsepower"].astype(float)

# %%
df["peak-rpm"] = df["peak-rpm"].astype(float)

# %%
df["price"] = df["price"].astype(float)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df['drive-wheels'] = df['drive-wheels'].replace('4wd','fwd')

# %%
df['drive-wheels'].value_counts()
# Out:
# drive-wheels
# fwd    129
# rwd     76
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df.dropna(subset = ['price'],inplace=True)

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    37
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
df.reset_index(drop=True,inplace=True)

# %%
df['normalized-losses']=df['normalized-losses'].fillna(df['normalized-losses'].mean()) 
# mode()[0]

# %%
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df['bore']=df['bore'].fillna(df['bore'].mean())

# %%
df['stroke']=df['stroke'].fillna(df['stroke'].mean())

# %%
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df['horsepower']=df['horsepower'].fillna(df['horsepower'].mean())

# %%
df['peak-rpm']=df['peak-rpm'].fillna(df['peak-rpm'].mean())

# %%
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df['num-of-doors']=df['num-of-doors'].fillna(df['num-of-doors'].mode())
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df['num-of-doors']=df['num-of-doors'].fillna(df['num-of-doors'].mode()[0])
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ## exploratory Data Analysis

# %% [markdown]
# # univariate analysis

# %%
df.head()
# Out:
#    symboling  normalized-losses        make fuel-type aspiration num-of-doors  \
# 0          3              122.0  alfa-romeo       gas        std          two
# 1          3              122.0  alfa-romeo       gas        std          two
# 2          1              122.0  alfa-romeo       gas        std          two
# 3          2              164.0        audi       gas        std         four
# 4          2              164.0        audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          fwd           front        99.4   176.6   66.4
#
# ...

# %%
df
# Out:
#      symboling  normalized-losses        make fuel-type aspiration  \
# 0            3              122.0  alfa-romeo       gas        std
# 1            3              122.0  alfa-romeo       gas        std
# 2            1              122.0  alfa-romeo       gas        std
# 3            2              164.0        audi       gas        std
# 4            2              164.0        audi       gas        std
# ..         ...                ...         ...       ...        ...
# 196         -1               95.0       volvo       gas        std
# 197         -1               95.0       volvo       gas      turbo
# 198         -1               95.0       volvo       gas        std
# 199         -1               95.0       volvo    diesel      turbo
# 200         -1               95.0       volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.kdeplot(df["symboling"], shade=True)
plt.title("Symboling Distribution")
plt.show()
print(df['symboling'].describe())
# Out:
# C:\Users\shana\AppData\Local\Temp\ipykernel_12704\1305705192.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["symboling"], shade=True)
# count    201.000000
# mean       0.840796
# std        1.254802
# min       -2.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        3.000000
# Name: symboling, dtype: float64

# %%
sns.kdeplot(df["normalized-losses"],shade=True)
plt.title("Normalized-Losses Graph")
plt.show()
print(df['normalized-losses'].describe())
# Out:
# C:\Users\shana\AppData\Local\Temp\ipykernel_12704\1697528265.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["normalized-losses"],shade=True)
# count    201.00000
# mean     122.00000
# std       31.99625
# min       65.00000
# 25%      101.00000
# 50%      122.00000
# 75%      137.00000
# max      256.00000
# Name: normalized-losses, dtype: float64

# %%
sns.kdeplot(df["wheel-base"],shade=True)
plt.title("Wheel Base Graph")
plt.show()
# Out:
# C:\Users\shana\AppData\Local\Temp\ipykernel_12704\547820223.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["wheel-base"],shade=True)

# %%
sns.kdeplot(df["length"],shade=True)
plt.title("Length of Car")
plt.show()
# Out:
# C:\Users\shana\AppData\Local\Temp\ipykernel_12704\650087864.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["length"],shade=True)

# %%
sns.kdeplot(df["width"],shade=True)
plt.title("Width of Car")
plt.show()
# Out:
# C:\Users\shana\AppData\Local\Temp\ipykernel_12704\1867238825.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["width"],shade=True)

# %%
sns.kdeplot(df["height"],shade=True)
plt.title("Height of Car")
plt.show()
# Out:
# C:\Users\shana\AppData\Local\Temp\ipykernel_12704\1745415195.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["height"],shade=True)

# %%
sns.kdeplot(df["curb-weight"],shade=True)
plt.title("Curb-Weight of Car")
plt.show()
# Out:
# C:\Users\shana\AppData\Local\Temp\ipykernel_12704\4049917125.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["curb-weight"],shade=True)

# %%
sns.violinplot(y=df["engine-size"])
plt.title("Violin Plot of Engine Size")
plt.show()

# %%
sns.violinplot(y=df["curb-weight"])
plt.title("Violin Plot of Curb Weight")
plt.show()

# %%
sns.violinplot(y=df["height"])
plt.title("Violin Plot of Height")
plt.show()

# %%
sns.violinplot(y=df["wheel-base"])
plt.title("Violin Plot of Wheel Base")
plt.show()

# %%
sns.stripplot(y=df["engine-size"],jitter=True)
plt.title("Strip Plot of Engine Size")
plt.show()

# %%
sns.stripplot(y=df["bore"],jitter=True)
plt.title("Strip Plot of Bore")
plt.show()

# %%
sns.stripplot(y=df["stroke"],jitter=True)
plt.title("Strip Plot of Stroke")
plt.show()

# %%
sns.violinplot(y=df["horsepower"])
plt.title("Strip Plot of Horsepower")
plt.show()

# %%
sns.histplot(df["curb-weight"], bins=20, kde=True)
plt.title("Histogram of Curb-Weight")
plt.show()

# %%
sns.histplot(df["normalized-losses"], bins=20, kde=True)
plt.title("Histogram of normalized-losses")
plt.show()

# %%
sns.boxplot(y=df["city-mpg"])
plt.title("Box Plot of City mpg")
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.scatterplot(x=df["length"], y=df["width"])
plt.title("Lenght v/s Width")
plt.show()

# %%
sns.scatterplot(x=df["height"],y=df["curb-weight"])
plt.title("Height v/s Curb-Weight")
plt.show()

# %%
sns.barplot(x=df["normalized-losses"],y=df["symboling"])
plt.title("Symboling v/s Normalized-losses")
plt.show()

# %%
sns.boxplot(x=df["body-style"],y=df["symboling"])
plt.title("Symboling of Body style")
plt.show()

# %%
sns.boxplot(x=df["engine-type"],y=df["engine-size"])
plt.title("Engine type v/s Engine size")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="make",y='price', hue="fuel-type", data=df)
plt.xticks(rotation=45)
plt.title("Make vs Price")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x="make",y="price", hue="horsepower",data=df)
plt.xticks(rotation=45)
plt.title("Horsepower according to Price")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x="make",y="price", hue="body-style",data=df)
plt.xticks(rotation=45)
plt.title("Body style according to Price")
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="make",y="price",data=df)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
lb_fueltype = LabelEncoder()
df['fuel-type']=lb_fueltype.fit_transform(df['fuel-type'])
print(lb_fueltype.classes_)
# Out:
# ['diesel' 'gas']

# %%
df
# Out:
#      symboling  normalized-losses        make  fuel-type aspiration  \
# 0            3              122.0  alfa-romeo          1        std
# 1            3              122.0  alfa-romeo          1        std
# 2            1              122.0  alfa-romeo          1        std
# 3            2              164.0        audi          1        std
# 4            2              164.0        audi          1        std
# ..         ...                ...         ...        ...        ...
# 196         -1               95.0       volvo          1        std
# 197         -1               95.0       volvo          1      turbo
# 198         -1               95.0       volvo          1        std
# 199         -1               95.0       volvo          0      turbo
# 200         -1               95.0       volvo          1      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
lb_aspiration = LabelEncoder()
df['aspiration']=lb_aspiration.fit_transform(df['aspiration'])
print(lb_aspiration.classes_)
# Out:
# ['std' 'turbo']

# %%
lb_num_of_doors = LabelEncoder()
df['num-of-doors']=lb_num_of_doors.fit_transform(df['num-of-doors'])
print(lb_num_of_doors.classes_)
# Out:
# ['four' 'two']

# %%
lb_body_style = LabelEncoder()
df['body-style']=lb_body_style.fit_transform(df['body-style'])
print(lb_body_style.classes_)
# Out:
# ['convertible' 'hardtop' 'hatchback' 'sedan' 'wagon']

# %%
lb_drive_wheels = LabelEncoder()
df['drive-wheels']=lb_drive_wheels.fit_transform(df['drive-wheels'])
print(lb_drive_wheels.classes_)
# Out:
# ['fwd' 'rwd']

# %%
lb_engine_location = LabelEncoder()
df['engine-location']=lb_engine_location.fit_transform(df['engine-location'])
print(lb_engine_location.classes_)
# Out:
# ['front' 'rear']

# %%
lb_engine_type = LabelEncoder()
df['engine-type']=lb_engine_type.fit_transform(df['engine-type'])
print(lb_engine_type.classes_)
# Out:
# ['dohc' 'l' 'ohc' 'ohcf' 'ohcv' 'rotor']

# %%
lb_num_of_cylinders = LabelEncoder()
df['num-of-cylinders']=lb_num_of_cylinders.fit_transform(df['num-of-cylinders'])
print(lb_num_of_cylinders.classes_)
# Out:
# ['eight' 'five' 'four' 'six' 'three' 'twelve' 'two']

# %%
Numerical_col = df.select_dtypes(include=['int64','float64']).columns.tolist()

# %%
for i in Numerical_col:
    sns.histplot(x=df[i],bins=20,kde=True)
    plt.title(i)
    plt.show()

# %%
categorical_col = df.select_dtypes(include=['object']).columns.tolist()

# %%
for i in categorical_col:
    sns.countplot(x=df[i])
    plt.xticks(rotation=90)
    plt.title(i)
    plt.show()

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type              int32
# aspiration             int32
# num-of-doors           int32
# body-style             int32
# drive-wheels           int32
# engine-location        int32
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type            int32
# num-of-cylinders       int32
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# pip install category_encoders

# %%
import category_encoders as ce

# Initialize the TargetEncoder
encoder = ce.TargetEncoder(cols=['make'])

# Fit and transform the data
df['make'] = encoder.fit_transform(df[['make']], df['price'])

# %%
df
# Out:
#      symboling  normalized-losses          make  fuel-type  aspiration  \
# 0            3              122.0  13561.040783          1           0
# 1            3              122.0  13561.040783          1           0
# 2            1              122.0  13561.040783          1           0
# 3            2              164.0  14127.377285          1           0
# 4            2              164.0  14127.377285          1           0
# ..         ...                ...           ...        ...         ...
# 196         -1               95.0  14610.773734          1           0
# 197         -1               95.0  14610.773734          1           1
# 198         -1               95.0  14610.773734          1           0
# 199         -1               95.0  14610.773734          0           1
# 200         -1               95.0  14610.773734          1           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
df['make'].unique()
# Out:
# array([13561.04078338, 14127.37728486, 16195.84953782, 12094.95946405,
#        11875.59492711, 11540.62332801, 12598.49901038, 16511.58478858,
#        12120.15042835, 17938.45283645, 13635.95005478, 11890.71075239,
#        11950.50775397, 13866.73147594, 12084.11208638, 16263.28113433,
#        12694.74495792, 13605.96698445, 11760.58768575, 10654.61503767,
#        12236.86438912, 14610.77373351])

# %%
encoder_fuel = ce.TargetEncoder(cols=['fuel-type'])
df['fuel-type'] = encoder_fuel.fit_transform(df[['fuel-type']], df['price'])

# %%
df['fuel-type'].unique()
# Out:
# array([12916.40886938, 14522.63967662])

# %%
df
# Out:
#      symboling  normalized-losses          make     fuel-type  aspiration  \
# 0            3              122.0  13561.040783  12916.408869           0
# 1            3              122.0  13561.040783  12916.408869           0
# 2            1              122.0  13561.040783  12916.408869           0
# 3            2              164.0  14127.377285  12916.408869           0
# 4            2              164.0  14127.377285  12916.408869           0
# ..         ...                ...           ...           ...         ...
# 196         -1               95.0  14610.773734  12916.408869           0
# 197         -1               95.0  14610.773734  12916.408869           1
# 198         -1               95.0  14610.773734  12916.408869           0
# 199         -1               95.0  14610.773734  14522.639677           1
# 200         -1               95.0  14610.773734  12916.408869           1
#
#      num-of-doors  body-style  drive-wheels  engine-location  wheel-base  \
# ...

# %%
corr_matrix = df.select_dtypes(include=['float64','int64']).corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
new_list = ['make','width','engine-size','horsepower','highway-mpg','price']
df = df[new_list]
df
# Out:
#              make  width  engine-size  horsepower  highway-mpg    price
# 0    13561.040783   64.1          130       111.0           27  13495.0
# 1    13561.040783   64.1          130       111.0           27  16500.0
# 2    13561.040783   65.5          152       154.0           26  16500.0
# 3    14127.377285   66.2          109       102.0           30  13950.0
# 4    14127.377285   66.4          136       115.0           22  17450.0
# ..            ...    ...          ...         ...          ...      ...
# 196  14610.773734   68.9          141       114.0           28  16845.0
# 197  14610.773734   68.8          141       160.0           25  19045.0
# 198  14610.773734   68.9          173       134.0           23  21485.0
# 199  14610.773734   68.9          145       106.0           27  22470.0
# 200  14610.773734   68.9          141       114.0           25  22625.0
#
# [201 rows x 6 columns]

# %%
corr_matrix = df.select_dtypes(include=['int64','float64']).corr()
plt.figure(figsize=(20,15))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.show()

# %%
x = df.drop(columns='price')
y = df['price']

# %%
x
# Out:
#              make  width  engine-size  horsepower  highway-mpg
# 0    13561.040783   64.1          130       111.0           27
# 1    13561.040783   64.1          130       111.0           27
# 2    13561.040783   65.5          152       154.0           26
# 3    14127.377285   66.2          109       102.0           30
# 4    14127.377285   66.4          136       115.0           22
# ..            ...    ...          ...         ...          ...
# 196  14610.773734   68.9          141       114.0           28
# 197  14610.773734   68.8          141       160.0           25
# 198  14610.773734   68.9          173       134.0           23
# 199  14610.773734   68.9          145       106.0           27
# 200  14610.773734   68.9          141       114.0           25
#
# [201 rows x 5 columns]

# %%
y
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
#         ...
# 196    16845.0
# 197    19045.0
# 198    21485.0
# 199    22470.0
# 200    22625.0
# Name: price, Length: 201, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#              make  width  engine-size  horsepower  highway-mpg
# 198  14610.773734   68.9          173       134.0           23
# 38   11540.623328   65.2          110        86.0           33
# 24   11875.594927   63.8           90        68.0           38
# 122  16263.281134   68.3          151       143.0           27
# 196  14610.773734   68.9          141       114.0           28
# ..            ...    ...          ...         ...          ...
# 106  13866.731476   68.4          120        97.0           24
# 14   16195.849538   66.9          209       182.0           22
# 92   11950.507754   63.8           97        69.0           37
# 179  12236.864389   65.5          109        85.0           34
# 102  11950.507754   67.9          181       200.0           23
#
# [160 rows x 5 columns]

# %%
x_test
# Out:
#              make  width  engine-size  horsepower  highway-mpg
# 95   11950.507754   63.8           97        69.0           37
# 15   16195.849538   67.9          209       182.0           22
# 30   11540.623328   63.9           92        76.0           38
# 158  10654.615038   64.4           98        70.0           34
# 128  13605.966984   66.5          121       110.0           28
# 115  12084.112086   63.8           90        68.0           41
# 69   17938.452836   70.5          234       155.0           18
# 171  10654.615038   66.5          122        92.0           32
# 175  10654.615038   67.7          171       161.0           24
# 45   16511.584789   69.6          258       176.0           19
# 66   17938.452836   70.3          183       123.0           25
# 183  12236.864389   65.5           97        68.0           42
# 165  10654.615038   65.6          146       116.0           30
# 78   11890.710752   65.4          122        88.0           32
# ...

# %%
y_train
# Out:
# 198    21485.0
# 38      8845.0
# 24      6692.0
# 122    22018.0
# 196    16845.0
#         ...
# 106    12440.0
# 14     30760.0
# 92      7799.0
# 179     7975.0
# 102    19699.0
# Name: price, Length: 160, dtype: float64

# %%
y_test
# Out:
# 95      8249.0
# 15     41315.0
# 30      6855.0
# 158     9258.0
# 128    11850.0
# 115     5572.0
# 69     35056.0
# 171     9988.0
# 175    15998.0
# 45     35550.0
# 66     28176.0
# 183     9495.0
# 165     9989.0
# 78      8499.0
# 187    13295.0
# 178     7775.0
# 56      8845.0
# 152     6938.0
# 82      6989.0
# 68     34184.0
# 124    34028.0
# 16     36880.0
# 148     6488.0
# 93      7499.0
# 65     28248.0
# 60     10795.0
# 84      9279.0
# 67     31600.0
# 125    37028.0
# 132    18150.0
# 9      16430.0
# 18      6295.0
# 55     15645.0
# 75      6669.0
# 150     7898.0
# 104    11900.0
# 135     7053.0
# 137     7126.0
# 164     9639.0
# 76      7689.0
# 79     12629.0
# Name: price, dtype: float64

# %%
print('Shape of x_train',x_train.shape)
print('Shape of x_test',x_test.shape)
print('Shape of y_train',y_train.shape)
print('Shape of y_test',y_test.shape)
# Out:
# Shape of x_train (160, 5)
# Shape of x_test (41, 5)
# Shape of y_train (160,)
# Shape of y_test (41,)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 1.24668252e+00,  1.54345420e+00,  1.21902002e+00,
#          9.00340847e-01, -1.16471216e+00],
#        [-6.41904116e-01, -2.98733071e-01, -3.70594701e-01,
#         -4.46433642e-01,  3.34515076e-01],
#        [-4.35848124e-01, -9.95776903e-01, -8.75234295e-01,
#         -9.51474076e-01,  1.08412869e+00],
#        [ 2.26321363e+00,  1.24472113e+00,  6.63916465e-01,
#          1.15286106e+00, -5.65021264e-01],
#        [ 1.24668252e+00,  1.54345420e+00,  4.11596668e-01,
#          3.39184810e-01, -4.15098540e-01],
#        [-6.41904116e-01, -9.45988058e-01, -8.24770335e-01,
#         -1.23205209e+00,  3.48289227e+00],
#        [-3.00907200e-01, -1.09535459e+00, -8.75234295e-01,
#         -8.95358472e-01,  1.83374231e+00],
#        [-5.06594215e-01, -1.99155381e-01, -4.21058661e-01,
#         -2.21971228e-01,  3.46696298e-02],
#        [-3.89765899e-01, -9.95776903e-01, -6.98610437e-01,
#         -9.23416274e-01,  9.34205970e-01],
# ...

# %%
x_test
# Out:
# array([[-3.89765899e-01, -9.95776903e-01, -6.98610437e-01,
#         -9.23416274e-01,  9.34205970e-01],
#        [ 2.22173344e+00,  1.04556575e+00,  2.12737129e+00,
#          2.24711534e+00, -1.31463488e+00],
#        [-6.41904116e-01, -9.45988058e-01, -8.24770335e-01,
#         -7.27011661e-01,  1.08412869e+00],
#        [-1.18692739e+00, -6.97043832e-01, -6.73378457e-01,
#         -8.95358472e-01,  4.84437800e-01],
#        [ 6.28581011e-01,  3.48521916e-01, -9.30429250e-02,
#          2.26953602e-01, -4.15098540e-01],
#        [-3.07579907e-01, -9.95776903e-01, -8.75234295e-01,
#         -9.51474076e-01,  1.53389686e+00],
#        [ 3.29368656e+00,  2.34007572e+00,  2.75817078e+00,
#          1.48955469e+00, -1.91432577e+00],
#        [-1.18692739e+00,  3.48521916e-01, -6.78109454e-02,
#         -2.78086831e-01,  1.84592353e-01],
#        [-1.18692739e+00,  9.45988058e-01,  1.16855606e+00,
#          1.65790150e+00, -1.01478943e+00],
# ...

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import accuracy_score
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.ensemble import RandomForestClassifier

# def tune_classifier(model_name, X_train_scaled, y_train, X_test_scaled, y_test):
#     model_dict = {
#         'knn': (KNeighborsClassifier(), {
#             'n_neighbors': [3, 5, 7, 9],
#             'weights': ['uniform', 'distance'],
#             'metric': ['euclidean', 'manhattan']
#         }),
#         'logistic': (LogisticRegression(solver='liblinear'), {
#             'C': [0.01, 0.1, 1, 10],
#             'penalty': ['l1', 'l2']
#         }),
#         'svm': (SVC(), {
#             'C': [0.1, 1, 10],
#             'kernel': ['linear', 'rbf'],
#             'gamma': ['scale', 'auto']
#         }),
#         'random_forest': (RandomForestClassifier(), {
#             'n_estimators': [100, 200],
#             'max_depth': [None, 10, 20],
#             'min_samples_split': [2, 5]
#         })
#     }

#     if model_name not in model_dict:
#         print("Unsupported classifier. Choose from:", list(model_dict.keys()))
#         return

#     model, param_grid = model_dict[model_name]
#     grid = GridSearchCV(model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
#     grid.fit(X_train_scaled, y_train)

#     print(f"\n📘 {model_name.upper()} Classifier Results:")
#     print("Best Params:", grid.best_params_)
#     print("Best CV Accuracy:", grid.best_score_)
#     print("Test Accuracy:", accuracy_score(y_test, grid.predict(X_test_scaled)))


from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
# from sklearn.linear_model import Ridge, Lasso
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import r2_score,mean_squared_error

def tune_regressor(model_name, x_train, y_train, x_test, y_test):
    model_dict = {
    'knn': (KNeighborsRegressor(), {
        'n_neighbors': [3, 5, 7, 9],
        'weights': ['uniform', 'distance'],
        'metric': ['euclidean', 'manhattan']
    }),

    'svr': (SVR(), {
        'C': [0.1, 1, 10],
        'kernel': ['rbf', 'linear'],
        'gamma': ['scale', 'auto']
    }),

    'random_forest': (RandomForestRegressor(), {
        'n_estimators': [100, 200],
        'max_depth': [None, 10, 20],
        'min_samples_split': [2, 5]
    }),

    'decision_tree': (DecisionTreeRegressor(), {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4]
    }),

    'adaboost': (AdaBoostRegressor(), {
        'n_estimators': [50, 100, 200],
        'learning_rate': [0.01, 0.1, 1],
        'loss': ['linear', 'square', 'exponential']
    })
    }
    if model_name not in model_dict:
        print("Unsupported regressor. Choose from:", list(model_dict.keys()))
        return

    model, param_grid = model_dict[model_name]
    grid = GridSearchCV(model, param_grid, cv=5, scoring='r2', n_jobs=-1)
    grid.fit(x_train, y_train)

    print(f"\n📗 {model_name.upper()} Regressor Results:")
    print("Best Params:", grid.best_params_)
    print("Best CV Score (R2):", grid.best_score_)
    print("Test MSE:", mean_squared_error(y_test, grid.predict(x_test)))




# For classifiers
# tune_classifier('knn', X_train_scaled, y_train, X_test_scaled, y_test)

# For regressors
tune_regressor('knn',x_train,y_train,x_test,y_test)
tune_regressor('svr',x_train,y_train,x_test,y_test)
tune_regressor('random_forest',x_train,y_train,x_test,y_test)
tune_regressor('decision_tree',x_train,y_train,x_test,y_test)
tune_regressor('adaboost',x_train,y_train,x_test,y_test)
# Out:
# 📗 KNN Regressor Results:
# Best Params: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# Best CV Score (R2): 0.8954475836747996
# Test MSE: 8764443.728008108
#
# 📗 SVR Regressor Results:
# Best Params: {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# Best CV Score (R2): 0.5404487560515439
# Test MSE: 70074319.64932418
#
# 📗 RANDOM_FOREST Regressor Results:
# Best Params: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 100}
# Best CV Score (R2): 0.8941994350926616
# Test MSE: 8308788.2523504
#
# 📗 DECISION_TREE Regressor Results:
# Best Params: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best CV Score (R2): 0.8793025773460466
# Test MSE: 9134894.367222497
#
# 📗 ADABOOST Regressor Results:
# Best Params: {'learning_rate': 1, 'loss': 'linear', 'n_estimators': 50}
# Best CV Score (R2): 0.8917139868143904
# Test MSE: 9910456.927301683

# %% [markdown]
# ### Cross Validation for KNN

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.neighbors import KNeighborsRegressor
knn_cv = KNeighborsRegressor(metric= 'euclidean', n_neighbors= 3, weights= 'distance')

# %%
kfold = KFold(n_splits=5,shuffle=True,random_state=42)

# %%
score = cross_val_score(knn_cv,x_train,y_train,cv=kfold)
print('Cross Validation Score :',score)
print('Mean Accuracy :',np.mean(score))
# Out:
# Cross Validation Score : [0.83561333 0.85265419 0.93619258 0.77672681 0.92760293]
# Mean Accuracy : 0.8657579668090403

# %% [markdown]
# ## KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
knn = KNeighborsRegressor(metric= 'euclidean', n_neighbors= 3, weights= 'distance')

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(metric='euclidean', n_neighbors=3, weights='distance')

# %%
knn.score(x_train,y_train)
# Out:
# 0.9834843455921073

# %%
knn.score(x_test,y_test)
# Out:
# 0.9283639158828929

# %%
new_datapoint = np.array([[11950.507754,63.8,97,69.0,37]])

# %%
new_datapoint = scaler.transform(new_datapoint)
# Out:
# C:\Users\shana\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
new_datapoint
# Out:
# array([[-0.3897659 , -0.9957769 , -0.69861044, -0.92341627,  0.93420597]])

# %%
knn.predict(new_datapoint)
# Out:
# array([6949.])

# %%
y_pred_knn=knn.predict(x_test)

# %%
y_pred_knn
# Out:
# array([ 6949.        , 31372.20279555,  6843.33333333,  8358.        ,
#        14240.        ,  5755.26133957, 33778.70618838, 11073.        ,
#        16558.        , 32250.        , 25552.        ,  6460.21420446,
#        13472.33333333,  8189.        , 14161.6911771 ,  7995.        ,
#        10695.        ,  7198.        ,  8189.        , 34303.98016292,
#        32528.        , 28828.05080066,  6338.        ,  6949.        ,
#        25552.        , 14320.3652065 ,  9619.        , 24150.66396917,
#        32528.        , 18620.        , 16925.        ,  6575.        ,
#        12145.        ,  6189.        ,  8778.        , 14535.        ,
#         7257.52744807,  8221.66666667, 13472.33333333,  8246.19844117,
#        14679.        ])

# %%
y_test
# Out:
# 95      8249.0
# 15     41315.0
# 30      6855.0
# 158     9258.0
# 128    11850.0
# 115     5572.0
# 69     35056.0
# 171     9988.0
# 175    15998.0
# 45     35550.0
# 66     28176.0
# 183     9495.0
# 165     9989.0
# 78      8499.0
# 187    13295.0
# 178     7775.0
# 56      8845.0
# 152     6938.0
# 82      6989.0
# 68     34184.0
# 124    34028.0
# 16     36880.0
# 148     6488.0
# 93      7499.0
# 65     28248.0
# 60     10795.0
# 84      9279.0
# 67     31600.0
# 125    37028.0
# 132    18150.0
# 9      16430.0
# 18      6295.0
# 55     15645.0
# 75      6669.0
# 150     7898.0
# 104    11900.0
# 135     7053.0
# 137     7126.0
# 164     9639.0
# 76      7689.0
# 79     12629.0
# Name: price, dtype: float64

# %%
result_knn=pd.DataFrame({'Actual':y_test,'Predicted':y_pred_knn})
result_knn
# Out:
#       Actual     Predicted
# 95    8249.0   6949.000000
# 15   41315.0  31372.202796
# 30    6855.0   6843.333333
# 158   9258.0   8358.000000
# 128  11850.0  14240.000000
# 115   5572.0   5755.261340
# 69   35056.0  33778.706188
# 171   9988.0  11073.000000
# 175  15998.0  16558.000000
# 45   35550.0  32250.000000
# 66   28176.0  25552.000000
# 183   9495.0   6460.214204
# 165   9989.0  13472.333333
# 78    8499.0   8189.000000
# 187  13295.0  14161.691177
# 178   7775.0   7995.000000
# 56    8845.0  10695.000000
# 152   6938.0   7198.000000
# 82    6989.0   8189.000000
# 68   34184.0  34303.980163
# 124  34028.0  32528.000000
# 16   36880.0  28828.050801
# 148   6488.0   6338.000000
# 93    7499.0   6949.000000
# 65   28248.0  25552.000000
# 60   10795.0  14320.365206
# 84    9279.0   9619.000000
# 67   31600.0  24150.663969
# 125  37028.0  32528.000000
# 132  18150.0  18620.000000
# 9    16430.0  16925.000000
# 18    6295.0   6575.000000
# 55   15645.0  12145.000000
# ...

# %%
mse = mean_squared_error(y_test,y_pred_knn)
mse
# Out:
# 8764443.728008108

# %%
msa = mean_absolute_error(y_test,y_pred_knn)
msa
# Out:
# 1955.1752638316982

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2960.4803204899213

# %% [markdown]
# ### Cross Validation For Linear Regression

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.linear_model import LinearRegression
lr_cv = LinearRegression()

# %%
kfold = KFold(n_splits=5,shuffle=True,random_state=42)

# %%
scores = cross_val_score(lr_cv,x_train,y_train,cv=kfold)
print('Cross Validation Score:',scores)
print('Mean Accuracy:',np.mean(scores))
# Out:
# Cross Validation Score: [0.79168789 0.87431554 0.92321276 0.82826248 0.89675493]
# Mean Accuracy: 0.8628467203627416

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.8944651318725448

# %%
model.score(x_test,y_test)
# Out:
# 0.8798659897403734

# %%
y_pred_model = model.predict(x_test)

# %%
result_model = pd.DataFrame({'Actual':y_test,'Predicted':y_pred_model})
result_model
# Out:
#       Actual     Predicted
# 95    8249.0   7549.680817
# 15   41315.0  27480.490357
# 30    6855.0   6860.803594
# 158   9258.0   6071.962103
# 128  11850.0  14608.562295
# 115   5572.0   7121.417658
# 69   35056.0  32140.172926
# 171   9988.0   9404.231858
# 175  15998.0  15755.378681
# 45   35550.0  31754.063929
# 66   28176.0  27448.405443
# 183   9495.0   8548.612335
# 165   9989.0  11408.599979
# 78    8499.0  10633.621170
# 187  13295.0  13814.210670
# 178   7775.0   7839.610804
# 56    8845.0  11356.399496
# 152   6938.0   5955.723938
# 82    6989.0  10633.621170
# 68   34184.0  32699.034445
# 124  34028.0  26035.017542
# 16   36880.0  28955.136266
# 148   6488.0   4888.645835
# 93    7499.0   7549.680817
# 65   28248.0  27448.405443
# 60   10795.0  10276.417308
# 84    9279.0  10923.145484
# 67   31600.0  28100.410549
# 125  37028.0  26035.017542
# 132  18150.0  16417.358504
# 9    16430.0  16585.220802
# 18    6295.0   7036.533705
# 55   15645.0  10447.226505
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse = mean_squared_error(y_test,y_pred_model)
mse
# Out:
# 14698008.49274794

# %%
msa = mean_absolute_error(y_test,y_pred_model)
msa
# Out:
# 2512.691011067361

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 3833.7981810142196

# %% [markdown]
# ### Cross Validation for Decision Tree

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.tree import DecisionTreeRegressor
dt_cv = DecisionTreeRegressor(max_depth=7)

# %%
kfold = KFold(n_splits=5,shuffle=True,random_state=42)

# %%
scores = cross_val_score(dt_cv,x_train,y_train,cv=kfold)
print('Cross Validation scores',scores)
print('Mean accuracy',np.mean(scores))
# Out:
# Cross Validation scores [0.81804789 0.78170494 0.92793567 0.649941   0.89174168]
# Mean accuracy 0.8138742378937881

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor(max_depth= 10, min_samples_leaf= 1, min_samples_split= 2)

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
tree.score(x_train,y_train)
# Out:
# 0.9843585233628489

# %%
tree.score(x_test,y_test)
# Out:
# 0.9308552508578539

# %%
y_pred_tree = tree.predict(x_test)
y_pred_tree
# Out:
# array([ 7062.81818182, 30760.        ,  6263.5       ,  8358.        ,
#        14240.        ,  5427.        , 32250.        , 11197.25      ,
#        16558.        , 32250.        , 25552.        ,  5427.        ,
#        12216.5       ,  8189.        , 18344.        ,  7995.        ,
#        10145.        ,  7198.        ,  8189.        , 32250.        ,
#        32528.        , 30760.        ,  6263.5       ,  7062.81818182,
#        25552.        , 13845.        ,  9518.5       , 25552.        ,
#        32528.        , 18620.        , 16925.        ,  6527.        ,
#        12145.        ,  6263.5       ,  8778.        , 14535.        ,
#         7684.75      ,  7198.        , 12216.5       ,  8257.5       ,
#        14679.        ])

# %%
result_tree = pd.DataFrame({'Actual':y_test,'Predicted':y_pred_tree})
result_tree
# Out:
#       Actual     Predicted
# 95    8249.0   7062.818182
# 15   41315.0  30760.000000
# 30    6855.0   6263.500000
# 158   9258.0   8358.000000
# 128  11850.0  14240.000000
# 115   5572.0   5427.000000
# 69   35056.0  32250.000000
# 171   9988.0  11197.250000
# 175  15998.0  16558.000000
# 45   35550.0  32250.000000
# 66   28176.0  25552.000000
# 183   9495.0   5427.000000
# 165   9989.0  12216.500000
# 78    8499.0   8189.000000
# 187  13295.0  18344.000000
# 178   7775.0   7995.000000
# 56    8845.0  10145.000000
# 152   6938.0   7198.000000
# 82    6989.0   8189.000000
# 68   34184.0  32250.000000
# 124  34028.0  32528.000000
# 16   36880.0  30760.000000
# 148   6488.0   6263.500000
# 93    7499.0   7062.818182
# 65   28248.0  25552.000000
# 60   10795.0  13845.000000
# 84    9279.0   9518.500000
# 67   31600.0  25552.000000
# 125  37028.0  32528.000000
# 132  18150.0  18620.000000
# 9    16430.0  16925.000000
# 18    6295.0   6527.000000
# 55   15645.0  12145.000000
# ...

# %%
mse = mean_squared_error(y_test,y_pred_tree)
mse
# Out:
# 8459636.933153598

# %%
mae = mean_absolute_error(y_test,y_pred_tree)
mae
# Out:
# 2004.069844789357

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2908.545501303632

# %% [markdown]
# ### Cross Validation for Random Forest

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import RandomForestRegressor
rf_cv=RandomForestRegressor(n_estimators=500,max_depth=7,random_state=42)

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
scores = cross_val_score(rf_cv, x_train, y_train, cv=kfold)

print("Cross-Validation Scores:", scores)
print("Mean Accuracy:", np.mean(scores))
# Out:
# Cross-Validation Scores: [0.8344328  0.90488394 0.95235051 0.82760463 0.93654861]
# Mean Accuracy: 0.8911640982787252

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random = RandomForestRegressor(max_depth= 20, min_samples_split= 2, n_estimators= 200)

# %%
random.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=200)

# %%
random.score(x_train,y_train)
# Out:
# 0.9772234753886133

# %%
random.score(x_test,y_test)
# Out:
# 0.9329948280666387

# %%
y_pred_rand = random.predict(x_test)
y_pred_rand
# Out:
# array([ 7075.50311078, 29831.355     ,  6806.44120833,  8195.08      ,
#        14265.53174603,  5844.97202381, 33035.49666667, 10909.21      ,
#        16849.91166667, 32866.35      , 25055.855     ,  7556.32364899,
#        12171.42819444,  8594.42547619, 14962.08659722,  7879.27212121,
#        10165.10686508,  7465.73238095,  8594.42547619, 34897.29666667,
#        30062.91875   , 31278.5175    ,  6465.0115    ,  7075.50311078,
#        25055.855     , 11731.07565476,  9648.49928571, 26909.205     ,
#        30062.91875   , 17650.05809524, 16065.8425    ,  6254.7725    ,
#        12604.66357143,  6349.55715476,  7659.35357143, 14588.70708333,
#         7550.02155095,  7698.54580267, 12171.42819444,  8378.49975   ,
#        14451.51571429])

# %%
result_rand = pd.DataFrame({'Actual':y_test,'Predicted':y_pred_rand})
result_rand
# Out:
#       Actual     Predicted
# 95    8249.0   7075.503111
# 15   41315.0  29831.355000
# 30    6855.0   6806.441208
# 158   9258.0   8195.080000
# 128  11850.0  14265.531746
# 115   5572.0   5844.972024
# 69   35056.0  33035.496667
# 171   9988.0  10909.210000
# 175  15998.0  16849.911667
# 45   35550.0  32866.350000
# 66   28176.0  25055.855000
# 183   9495.0   7556.323649
# 165   9989.0  12171.428194
# 78    8499.0   8594.425476
# 187  13295.0  14962.086597
# 178   7775.0   7879.272121
# 56    8845.0  10165.106865
# 152   6938.0   7465.732381
# 82    6989.0   8594.425476
# 68   34184.0  34897.296667
# 124  34028.0  30062.918750
# 16   36880.0  31278.517500
# 148   6488.0   6465.011500
# 93    7499.0   7075.503111
# 65   28248.0  25055.855000
# 60   10795.0  11731.075655
# 84    9279.0   9648.499286
# 67   31600.0  26909.205000
# 125  37028.0  30062.918750
# 132  18150.0  17650.058095
# 9    16430.0  16065.842500
# 18    6295.0   6254.772500
# 55   15645.0  12604.663571
# ...

# %%
mse = mean_squared_error(y_test,y_pred_rand)
mse
# Out:
# 8197866.5658975085

# %%
mae = mean_absolute_error(y_test,y_pred_rand)
mae
# Out:
# 1845.8807466395392

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2863.1916746696347

# %% [markdown]
# ### Cross Validation for ADA Boost Regressor

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.ensemble import AdaBoostRegressor
ada_cv = AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=5),learning_rate=0.2,random_state=42,n_estimators=100)

# %%
kfold = KFold(n_splits=5,shuffle=True,random_state=42)

# %%
score = cross_val_score(ada_cv,x_train,y_train,cv=kfold)
print('Cross validation Score :',score)
print('Mean Accuracy :',np.mean(score))
# Out:
# Cross validation Score : [0.75698985 0.8293901  0.93315542 0.79843846 0.96089545]
# Mean Accuracy : 0.8557738526476226

# %% [markdown]
# ## ADA Boost Regressor

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada = AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth= 10),learning_rate= 0.1, loss= 'exponential', n_estimators=200)

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=10),
#                   learning_rate=0.1, loss='exponential', n_estimators=200)

# %%
ada.score(x_train,y_train)
# Out:
# 0.982747946114953

# %%
ada.score(x_test,y_test)
# Out:
# 0.938796955586414

# %%
y_pred_ada = ada.predict(x_test)
y_pred_ada
# Out:
# array([ 6984.71428571, 30760.        ,  6785.        ,  8058.        ,
#        13860.        ,  6229.        , 32250.        , 10898.        ,
#        16558.        , 32250.        , 25552.        ,  7975.        ,
#        13085.625     ,  8921.        , 14312.85714286,  7995.        ,
#        10165.        ,  7609.        ,  8921.        , 32528.        ,
#        32528.        , 30760.        ,  6479.        ,  6984.71428571,
#        25552.        , 10698.        ,  9789.        , 25552.        ,
#        32528.        , 18344.        , 16925.        ,  6575.        ,
#        12359.28571429,  6670.42857143,  8357.66666667, 14535.        ,
#         7603.        ,  7775.        , 13085.625     ,  8558.        ,
#        14489.        ])

# %%
result_ada = pd.DataFrame({'Actual':y_test,'Predicted':y_pred_ada})
result_ada
# Out:
#       Actual     Predicted
# 95    8249.0   6984.714286
# 15   41315.0  30760.000000
# 30    6855.0   6785.000000
# 158   9258.0   8058.000000
# 128  11850.0  13860.000000
# 115   5572.0   6229.000000
# 69   35056.0  32250.000000
# 171   9988.0  10898.000000
# 175  15998.0  16558.000000
# 45   35550.0  32250.000000
# 66   28176.0  25552.000000
# 183   9495.0   7975.000000
# 165   9989.0  13085.625000
# 78    8499.0   8921.000000
# 187  13295.0  14312.857143
# 178   7775.0   7995.000000
# 56    8845.0  10165.000000
# 152   6938.0   7609.000000
# 82    6989.0   8921.000000
# 68   34184.0  32528.000000
# 124  34028.0  32528.000000
# 16   36880.0  30760.000000
# 148   6488.0   6479.000000
# 93    7499.0   6984.714286
# 65   28248.0  25552.000000
# 60   10795.0  10698.000000
# 84    9279.0   9789.000000
# 67   31600.0  25552.000000
# 125  37028.0  32528.000000
# 132  18150.0  18344.000000
# 9    16430.0  16925.000000
# 18    6295.0   6575.000000
# 55   15645.0  12359.285714
# ...

# %%
mse = mean_squared_error(y_test,y_pred_ada)
mse
# Out:
# 7487994.986838739

# %%
mae = mean_absolute_error(y_test,y_pred_ada)
mae
# Out:
# 1817.8411730545877

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 2736.420104230843

# %% [markdown]
# ### Cross Validation For SVR

# %%
from sklearn.model_selection import KFold,cross_val_score
from sklearn.svm import SVR
svr_cv = SVR(C=10, gamma='scale', kernel='linear')

# %%
kfold = KFold(n_splits=5,shuffle=True,random_state=42)

# %%
score = cross_val_score(svr_cv,x_train,y_train,cv=kfold)
print('Cross Validation Score :',score)
print('Mean Accuracy :',np.mean(score))
# Out:
# Cross Validation Score : [0.58428952 0.52691024 0.57295979 0.51257197 0.4964883 ]
# Mean Accuracy : 0.5386439623633534

# %% [markdown]
# ## Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
svr = SVR(C=10, gamma='scale', kernel='linear')

# %%
svr.fit(x_train,y_train)
# Out:
# SVR(C=10, kernel='linear')

# %%
svr.score(x_train,y_train)
# Out:
# 0.5891518259340173

# %%
svr.score(x_test,y_test)
# Out:
# 0.4272483214415145

# %%
y_pred_svr = svr.predict(x_test)
y_pred_svr
# Out:
# array([ 8382.90488492, 17535.06235192,  8213.26001937,  8393.14165163,
#        12291.3085952 ,  7922.33060761, 19579.1043629 , 10300.74374796,
#        13812.44115533, 19360.63628064, 17297.98899157,  8702.38896419,
#        11035.16332214, 10299.82250456, 12504.0346089 ,  7994.89998492,
#        10760.21502368,  8111.00609736, 10299.82250456, 20064.94278377,
#        16366.6583746 , 18937.74877361,  7423.97809691,  8382.90488492,
#        17297.98899157,  9405.62787581, 10860.82946452, 17864.80048258,
#        16366.6583746 , 13514.73721547, 12203.23585283,  7699.30765636,
#        11614.71951676,  8399.36867004,  7988.24920546, 13261.53547362,
#         9057.65284054,  9408.50024843, 11035.16332214,  9716.27736317,
#        13182.98808907])

# %%
result_svr = pd.DataFrame({'Actual':y_test,'Predicted':y_pred_svr})
result_svr
# Out:
#       Actual     Predicted
# 95    8249.0   8382.904885
# 15   41315.0  17535.062352
# 30    6855.0   8213.260019
# 158   9258.0   8393.141652
# 128  11850.0  12291.308595
# 115   5572.0   7922.330608
# 69   35056.0  19579.104363
# 171   9988.0  10300.743748
# 175  15998.0  13812.441155
# 45   35550.0  19360.636281
# 66   28176.0  17297.988992
# 183   9495.0   8702.388964
# 165   9989.0  11035.163322
# 78    8499.0  10299.822505
# 187  13295.0  12504.034609
# 178   7775.0   7994.899985
# 56    8845.0  10760.215024
# 152   6938.0   8111.006097
# 82    6989.0  10299.822505
# 68   34184.0  20064.942784
# 124  34028.0  16366.658375
# 16   36880.0  18937.748774
# 148   6488.0   7423.978097
# 93    7499.0   8382.904885
# 65   28248.0  17297.988992
# 60   10795.0   9405.627876
# 84    9279.0  10860.829465
# 67   31600.0  17864.800483
# 125  37028.0  16366.658375
# 132  18150.0  13514.737215
# 9    16430.0  12203.235853
# 18    6295.0   7699.307656
# 55   15645.0  11614.719517
# ...

# %%
mse = mean_squared_error(y_test,y_pred_svr)
mse
# Out:
# 70074319.64932418

# %%
mae = mean_absolute_error(y_test,y_pred_svr)
mae
# Out:
# 5137.178438994418

# %%
rmse = np.sqrt(mse)
rmse
# Out:
# 8371.040535639771
